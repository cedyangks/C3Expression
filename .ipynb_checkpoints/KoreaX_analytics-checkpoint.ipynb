# %%
import numpy as np
import pandas as pd
import pandas_datareader as pdr
import time
import scipy
import json
import os
import datetime
import glob
import sys
import yfinance as yf
from selenium import webdriver
from IPython.display import display

# %%
def KRX_site()->webdriver.firefox.webdriver.WebDriver:
    #Query for certain stocks that are worth shorting
    BrowserKRX:list=[webdriver.firefox.webdriver.WebDriver] * 5;
    pass;
    BrowserKRX[0]=webdriver.Firefox();
    BrowserKRX[0].get('http://data.krx.co.kr/contents/MDC/MAIN/main/index.cmd');
    BrowserKRX[0].find_element(webdriver.common.by.By.XPATH,'/html/body/div[2]/section[1]/div[1]/div[2]/button').click();
    time.sleep(2);
    BrowserKRX[0].get('http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC0203')
    time.sleep(2);
    print(type(BrowserKRX[0]));
    return BrowserKRX[0];

# %%
print(type(webdriver.Firefox));
WebPage:webdriver.firefox.webdriver.WebDriver=KRX_site();
WebPage.find_element(webdriver.common.by.By.LINK_TEXT,'Short-selling transaction').click();
time.sleep(2);
WebPage.find_element(webdriver.common.by.By.LINK_TEXT,'Top 50 in short-selling transaction').click();
time.sleep(2);
WebPage.find_element(webdriver.common.by.By.XPATH,'//*[@id="jsMdiMenu"]/div[4]/ul/li[3]/ul/li[2]/div/div[1]/ul/li[2]/ul/li[4]/a').click();
time.sleep(2);
WebPage.find_element(webdriver.common.by.By.XPATH,'//*[@id="MDCSTAT304_FORM"]/div[2]/div/p[2]/button[2]/img').click();
time.sleep(2);
WebPage.find_element(webdriver.common.by.By.LINK_TEXT,'Excel').click();
time.sleep(2);
#close the firefox webbrowser
WebPage.close();
# Out:
# <class 'abc.ABCMeta'>
# <class 'selenium.webdriver.firefox.webdriver.WebDriver'>

# %%
print(type(datetime.date.today()));
TodayDate:datetime.date=datetime.date.today();
InputStr:str=datetime.datetime.strftime(TodayDate,'%Y%m%d');
QueryFile_Str:str='/Users/cedricyang/Downloads/data_*_'+InputStr+'*.xlsx';
print(QueryFile_Str);
PathFile_List:list=glob.glob(QueryFile_Str);
print(PathFile_List);
try:
    KoreaSummary:pd.DataFrame=pd.read_excel(io=PathFile_List[0],engine='openpyxl');
except FileNotFoundError as FileRelatedErrno:
    print("check paths first");
ColumnsStorage:list=list(KoreaSummary.columns.values);
StrIssueCode:list=str(KoreaSummary[ColumnsStorage[1]][3]);
StrIssueCode='0'+StrIssueCode;

#creating a list comprehension style
KoreaSummary['Str Issue Code']=[str(i) for i in KoreaSummary[ColumnsStorage[1]] ];
# Out:
# <class 'datetime.date'>
# /Users/cedricyang/Downloads/data_*_20230417*.xlsx
# ['/Users/cedricyang/Downloads/data_3047_20230417.xlsx', '/Users/cedricyang/Downloads/data_3628_20230417.xlsx']

# %%
DictWithKey:dict=dict.fromkeys([1,2,3,4,5]);
#setting up the dict with Function pointer
def AppendZero1(ArgStr:str)->str:
    print('AppendZero1');
    pass;
    LengthOfStr:int=len(ArgStr);
    ArgStr='0'+ArgStr;
    return ArgStr;

def AppendZero2(ArgStr:str)->str:
    print('AppendZero2');
    pass;
    LengthOfStr:int=len(ArgStr);
    ArgStr='00'+ArgStr;
    return ArgStr;
    
def AppendZero3(ArgStr:str)->str:
    print('AppendZero3');
    pass;
    LengthOfStr:int=len(ArgStr);
    ArgStr='000'+ArgStr;
    return ArgStr;

def AppendZero4(ArgStr:str)->str:
    print('AppendZero4');
    pass;
    LengthOfStr:int=len(ArgStr);
    ArgStr='0000'+ArgStr;
    return ArgStr;

def AppendZero5(ArgStr:str)->str:
    print('AppendZero5');
    pass;
    LengthOfStr:int=len(ArgStr);
    ArgStr='00000'+ArgStr;
    return ArgStr;
    
DictWithKey[1]=AppendZero1;
DictWithKey[2]=AppendZero2;
DictWithKey[3]=AppendZero3;
DictWithKey[4]=AppendZero4;
DictWithKey[5]=AppendZero5;

LoopCounter:int=0;
for i in KoreaSummary['Str Issue Code']:
    if (len(i)<6):
        KoreaSummary['Str Issue Code'][LoopCounter]=DictWithKey[6-len(i)](i);
        LoopCounter=LoopCounter+1;
        continue;
    LoopCounter=LoopCounter+1;
    continue;
# Out:
# AppendZero1
# AppendZero1
# AppendZero1
# AppendZero1
# AppendZero1
# AppendZero2
# AppendZero1
# AppendZero2
# AppendZero2
# AppendZero1
# AppendZero1
# AppendZero1
# AppendZero2
# AppendZero1
# AppendZero3
# AppendZero2
# AppendZero2
# AppendZero1
# AppendZero1
# AppendZero1
# AppendZero1
# AppendZero3
# AppendZero2
# AppendZero2
# AppendZero2
# AppendZero2
# AppendZero2
# AppendZero2
# AppendZero2
# AppendZero2
# AppendZero2
# AppendZero1
# AppendZero1
# AppendZero1
# AppendZero1
# AppendZero2
# AppendZero2
# AppendZero1
# /var/folders/rx/v395xfy959n8xn9cpkxbqbk80000gn/T/ipykernel_43576/2031939244.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KoreaSummary['Str Issue Code'][LoopCounter]=DictWithKey[6-len(i)](i);
#     Rank  Issue code                   Issue name  Short-selling value  \
# 0      1       23530               LOTTE SHOPPING           2528764300
# 1      2       12750                          S-1           1227241900
# 2      3       81660                Fila Holdings           1842428700
# 3      4       31430      SHINSEGAE INTERNATIONAL            788231800
# 4      5       30000               CheilWorldwide           2666684170
# 5      6        3230                  SamyangFood           2546847300
# 6      7       10950                        S-Oil           4797262500
# 7      8        4370                     Nongshim           1214440000
# 8      9        9240                      Hanssem            333782400
# 9     10       55550                 ShinhanGroup          11372385800
# 10    11       11790                          SKC           6095485800
# 11    12       34220                   LG Display           8781663450
# 12    13        7070                    GS Retail           1254160500
# 13    14       29780                 SAMSUNG CARD            441748650
# 14    15         810                SamsungF&MIns           3320038000
# 15    16        1040                           CJ           3168130100
# 16    17        1450              Hyundai M&F INS           1372695550
# 17    18      241560                Doosan Bobcat           2791293250
# 18    19      139130          DGB Financial Group            881593840
# 19    20       17800                  HyundaiElev           6863682900
# 20    21      180640                    HANJINKAL            398651500
# 21    22       11210                  HYUNDAI WIA           4144140700
# 22    23       20150  LOTTE ENERGY MATERIALS Corp           3404491300
# 23    24      271560                        ORION           1510389800
# 24    25       13890                        ZINUS            300652200
# 25    26         240            HANKOOK & COMPANY            178959290
# 26    27        2790                       AmoreG           1844202550
# 27    28        5830                 DB INSURANCE           1617636000
# 28    29        1680                      Daesang            240702650
# 29    30      241590               H.S.ENTERPRISE            204851880
# 30    31        6650                         KPIC            787813500
# 31    32        8930                Hanmi Science           1836640450
# 32    33        1740                   SKNetworks            586393985
# 33    34      138040             Meritz Financial           3204438700
# 34    35        6040                   DongwonInd            200588900
# 35    36        4000              LOTTE Fine Chem            395321800
# 36    37        1800               ORION Holdings            144174360
# 37    38       32830                 SAMSUNG LIFE           2043251800
# 38    39       18880                Hanon Systems            981129570
# 8                                   0.58
# 9                                   2.05
# 10                                  1.02
# 11                                  2.56
# 12                                  1.86
# 13                                  2.01
# 14                                  1.82
# 15                                  2.46
# 16                                  0.84
# 17                                  1.38
# 18                                  1.87
# 19                                  6.68
# 20                                  0.54
# 21                                  4.59
# 22                                  1.25
# 23                                  0.81
# 24                                  2.10
# 25                                  2.25
# 26                                  1.51
# 27                                  0.85
# 28                                  0.78
# 29                                  1.50
# 30                                  0.62
# 31                                  1.39
# 32                                  0.79
# 33                                  1.03
# 34                                  0.40
# 35                                  1.45
# 36                                  1.30
# 37                                  1.07
# 38                                  1.33
# 39                                  2.79
# 40                                  0.99
# 41                                  0.85
# 42                                  0.86
# 43                                  1.04
# 44                                  4.10
# 45                                  0.58
# 46                                  1.38
# 47                                  1.32
# 48                                  0.85
# 49                                  0.65
#
#     Avg. short-selling ratio of the last 40 trading days  \
# 0                                               34.94
# 1                                               39.83
# 2                                               20.37
# 3                                               11.10
# 4                                               22.36
# 5                                                2.12
# 6                                               10.46
# 7                                               13.32
# 8                                               19.47
# 9                                               10.76
# 10                                              11.57
# 11                                              12.48
# 12                                              11.03
# 13                                              11.53
# 14                                              11.01
# 15                                              14.54
# 16                                              12.01
# 17                                              14.19
# 18                                               6.00
# 19                                              14.00
# 20                                              16.44
# 21                                               7.29
# 22                                               7.91
# 23                                              14.97
# 24                                               8.85
# 25                                              10.41
# 26                                              12.15
# 27                                              13.07
# 28                                              18.54
# 29                                               8.44
# 30                                              13.54
# 31                                              11.41
# 32                                              14.22
# 33                                              11.04
# 34                                              19.82
# 35                                               6.92
# 36                                               9.47
# 37                                              14.72
# 38                                              10.22
# 39                                               7.38
# 40                                              10.36
# 41                                              13.60
# 42                                              15.88
# 43                                               8.31
# 44                                               5.25
# 45                                              12.94
# 46                                               8.11
# 47                                               8.49
# 48                                              11.24
# 49                                              11.39
#
#     Increase rate of short-selling ratio  Price change rate Str Issue Code
# 0                                   1.15               1.71         023530
# 1                                   0.85               0.00         012750
# 2                                   1.53              -0.41         081660
# 3                                   2.78               0.24         031430
# 4                                   1.36              -0.36         030000
# 5                                  12.32              -0.49         003230
# 6                                   2.34              -0.84         010950
# 7                                   1.83              -2.84         004370
# 8                                   1.18              -1.40         009240
# 9                                   1.98               1.29         055550
# 10                                  1.82               1.10         011790
# 11                                  1.66              -1.60         034220
# 12                                  1.84              -0.72         007070
# 13                                  1.62              -0.33         029780
# 14                                  1.70               0.97         000810
# 15                                  1.27              -1.27         001040
# 16                                  1.49              -0.15         001450
# 17                                  1.23               1.30         241560
# 18                                  2.87               0.43         139130
# 19                                  1.23              -8.51         017800
# 20                                  1.03              -1.02         180640
# 21                                  2.16              -1.84         011210
# 22                                  1.90               0.14         020150
# 23                                  0.99              -0.30         271560
# 24                                  1.67               0.83         013890
# 25                                  1.41               0.57         000240
# 26                                  1.20               2.02         002790
# 27                                  1.11               1.04         005830
# 28                                  0.77              -0.05         001680
# 29                                  1.66               0.23         241590
# 30                                  1.00               1.20         006650
# 31                                  1.18               0.98         008930
# 32                                  0.94              -1.25         001740
# 33                                  1.21              -2.09         138040
# 34                                  0.66               0.00         006040
# 35                                  1.85              -0.67         004000
# 36                                  1.35              -1.06         001800
# 37                                  0.87               0.94         032830
# 38                                  1.24               1.10         018880
# 39                                  1.69               0.38         284740
# 40                                  1.20              -0.97         020000
# 41                                  0.89               0.39         021240
# 42                                  0.75               0.00         006800
# 43                                  1.44              -0.31         336260
# 44                                  2.25              -3.17         005850
# 45                                  0.90              -0.20         139480
# 46                                  1.43               1.33         028050
# 47                                  1.33              -0.83         373220
# 48                                  0.99              -1.13         204320
# 49                                  0.96              -1.03         175330

# %%
TickerKRX:list=['SK Hynix','302440','109070','LG DISPLAY','SAMSUNG BIOLOGICS','SAMSUNG LIFE','066570','005930','HYUNDAI CORP','032350','003550','323410','377300','293490']
def TickerQuery(StockList:list,Sel_DriverObj:webdriver.firefox.webdriver.WebDriver):
    Sel_DriverObj.find_element(webdriver.common.by.By.XPATH,'//*[@id="tboxisuCd_finder_srtisu0_0"]').clear();
    i:int=len(TickerKRX)
    print(i, " ",hex(id(i))); #heap mem addr on python
    time.sleep(2);
    for i in range(i):
        Sel_DriverObj.find_element(webdriver.common.by.By.XPATH,'//*[@id="tboxisuCd_finder_srtisu0_0"]').send_keys(TickerKRX[i]);
        time.sleep(2);
        Sel_DriverObj.find_element(webdriver.common.by.By.XPATH,'//*[@id="tboxisuCd_finder_srtisu0_0"]').send_keys(webdriver.common.keys.Keys.ENTER);
        time.sleep(2);
        Sel_DriverObj.find_element(webdriver.common.by.By.XPATH,'//*[@id="jsSearchButton"]').click();
        time.sleep(2);
        Sel_DriverObj.find_element(webdriver.common.by.By.CLASS_NAME,'CI-MDI-UNIT-DOWNLOAD').click();
        time.sleep(2);
        Sel_DriverObj.find_element(webdriver.common.by.By.LINK_TEXT,'Excel').click();
        time.sleep(2)
        Sel_DriverObj.find_element(webdriver.common.by.By.XPATH,'//*[@id="tboxisuCd_finder_srtisu0_0"]').clear();
        time.sleep(2);
    pass;
    Sel_DriverObj.close();
    #shut the webbrowser;
    return;

TickerQuery(TickerKRX,WebPage);
# Out:
# 14   0x7f961802ead0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 26
#      23     return;
#      25 TickerQuery(TickerKRX,WebPage);
# ---> 26 pd.read_excel()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py:299, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     294     msg = (
#     295         f"Starting with Pandas version {version} all arguments of "
#     296         f"{func.__name__}{arguments} will be keyword-only"
#     297     )
#     298     warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299 return func(*args, **kwargs)
#
# TypeError: read_excel() missing 1 required positional argument: 'io'

# %%
FileType:str='.xlsx'
FileList:list=os.listdir('/Users/cedricyang/Downloads/');
print(len(FileList));
ReadExcel:list=[str]*30;
xlsxCounter:int=0
for i in FileList:
    if (i.endswith('.xlsx')):
        ReadExcel[xlsxCounter]=i;
        xlsxCounter=xlsxCounter+1;
        continue;
    else:
        continue;
print(ReadExcel);
print('/Users/cedricyang/Downloads/'+ReadExcel[0]);
print(type('/Users/cedricyang/Downloads/'+ReadExcel[0]));
# Out:
# 83
# ['data_4257_20230411.xlsx', 'Short Sales_12-04-2023 to 12-04-2023.xlsx', 'Equities_9988.xlsx', 'Short Sales_07-04-2023 to 07-04-2023.xlsx', 'data_4901_20230414.xlsx', 'data_3431_20230403.xlsx', 'data_5244_20230414.xlsx', <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]
# /Users/cedricyang/Downloads/data_4257_20230411.xlsx
# <class 'str'>

# %%
ChainOpt=yf.Ticker('CCJ');
ExpiryDate:tuple=ChainOpt.options;
TupLength:int=len(ExpiryDate);
ListDF:list=[pd.DataFrame] * TupLength;
ListDF[1]=ChainOpt.option_chain(ExpiryDate[1]).puts;
ListDF[2]=ChainOpt.option_chain(ExpiryDate[2]).puts;
print(ListDF[1].columns.values);
ListDF[3]=ListDF[1].append(ListDF[2],ignore_index=True);
print(ListDF[3].shape);
display(ListDF[3]);
# Out:
# ['contractSymbol' 'lastTradeDate' 'strike' 'lastPrice' 'bid' 'ask'
#  'change' 'percentChange' 'volume' 'openInterest' 'impliedVolatility'
#  'inTheMoney' 'contractSize' 'currency']
# (54, 14)
# /var/folders/c1/njhn_k9n4y9cr296hv6sy1n00000gn/T/ipykernel_13505/2828055315.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ListDF[3]=ListDF[1].append(ListDF[2],ignore_index=True);
#         contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0   CCJ230421P00017000 2023-03-24 13:44:44+00:00    17.0       0.05  0.00
# 1   CCJ230421P00018000 2023-03-21 13:32:50+00:00    18.0       0.04  0.00
# 2   CCJ230421P00018500 2023-04-06 15:28:35+00:00    18.5       0.01  0.00
# 3   CCJ230421P00019000 2023-04-04 15:56:39+00:00    19.0       0.01  0.00
# 4   CCJ230421P00019500 2023-04-03 14:24:00+00:00    19.5       0.02  0.00
# 5   CCJ230421P00020000 2023-04-05 13:52:16+00:00    20.0       0.02  0.00
# 6   CCJ230421P00020500 2023-03-28 19:56:01+00:00    20.5       0.07  0.00
# 7   CCJ230421P00021000 2023-04-03 16:12:22+00:00    21.0       0.04  0.00
# 8   CCJ230421P00021500 2023-03-30 14:47:26+00:00    21.5       0.11  0.00
# 9   CCJ230421P00022000 2023-04-05 19:20:54+00:00    22.0       0.09  0.00
# 10  CCJ230421P00022500 2023-04-04 15:30:10+00:00    22.5       0.11  0.00
# 11  CCJ230421P00023000 2023-04-06 17:49:43+00:00    23.0       0.13  0.00
# 12  CCJ230421P00023500 2023-04-06 16:39:16+00:00    23.5       0.20  0.00
# 13  CCJ230421P00024000 2023-04-06 19:24:52+00:00    24.0       0.26  0.00
# 14  CCJ230421P00024500 2023-04-06 18:01:04+00:00    24.5       0.43  0.00
# 15  CCJ230421P00025000 2023-04-06 18:31:29+00:00    25.0       0.57  0.00
# 16  CCJ230421P00025500 2023-04-05 15:36:07+00:00    25.5       0.82  0.00
# 17  CCJ230421P00026000 2023-04-05 19:51:57+00:00    26.0       1.24  0.00
# 18  CCJ230421P00026500 2023-04-06 13:36:50+00:00    26.5       1.82  0.00
# 19  CCJ230421P00027000 2023-04-06 17:52:47+00:00    27.0       1.94  0.00
# 20  CCJ230421P00027500 2023-03-31 15:32:08+00:00    27.5       1.62  0.00
# 21  CCJ230421P00028000 2023-04-04 15:29:34+00:00    28.0       2.72  0.00
# 22  CCJ230421P00028500 2023-03-30 19:13:06+00:00    28.5       2.53  0.00
