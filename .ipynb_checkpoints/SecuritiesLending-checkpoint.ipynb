# %%
import json
import glob
import bs4
import os
import pandas as pd
import pandas_datareader as pdr
import numpy as np
from selenium import webdriver
import yfinance as yf
import time
import scipy
import datetime
from IPython.display import display

# %%
DFList:list=[pd.DataFrame] * 5;
#perform arithmetic operations on date
#print(datetime.datetime.today().strftime('%d-%m-%Y')-datetime.timedelta(days=1));
print(type(datetime.datetime.today()-datetime.timedelta(days=2)));
DateConvert_Str:datetime.datetime=datetime.datetime.today()-datetime.timedelta(days=1);
DateString:str=datetime.datetime.strftime(DateConvert_Str,'%d-%m-%Y');
ThaiSS_FileStr:str='/Users/cedricyang/Downloads/Short Sales_'+DateString+' to '+DateString+'.xlsx';
print(ThaiSS_FileStr);
#or implement checks to see if the files was downloaded successfully
DirListFile:list=os.listdir('/Users/cedricyang/Downloads/');
List_of_file:list=glob.glob('/Users/cedricyang/Downloads/*.xlsx');
print(List_of_file)
NameString:str='/Users/cedricyang/Downloads/';
# Out:
# <class 'datetime.datetime'>
# /Users/cedricyang/Downloads/Short Sales_11-04-2023 to 11-04-2023.xlsx
# ['/Users/cedricyang/Downloads/data_4257_20230411.xlsx', '/Users/cedricyang/Downloads/Short Sales_10-04-2023 to 10-04-2023.xlsx', '/Users/cedricyang/Downloads/Equities_9988.xlsx', '/Users/cedricyang/Downloads/Short Sales_11-04-2023 to 11-04-2023.xlsx', '/Users/cedricyang/Downloads/Short Sales_07-04-2023 to 07-04-2023.xlsx', '/Users/cedricyang/Downloads/data_3431_20230403.xlsx', '/Users/cedricyang/Downloads/Short Sales_10-04-2023 to 10-04-2023(1).xlsx']

# %%
FileIO=open('IRSG.json','r');
DictObjs:dict=json.load(FileIO);
DFList[0]:pd.DataFrame=pd.json_normalize(DictObjs,record_path=['result','records']);
Sora_Quantile=DFList[0]['comp_sora_3m'].quantile([0.25,0.5,0.75,0.95,1.0]).to_dict();
DFList[0]['Indicator']=DFList[0]['comp_sora_3m']>DFList[0]['comp_sora_1m'];
display(DFList[0][DFList[0]['Indicator']==True][:30]);
# Out:
#      end_of_day  comp_sora_1m  comp_sora_3m  comp_sora_6m  aggregate_volume  \
# 1    2023-04-11        3.6116        3.6123        3.3192            2554.0
# 56   2023-01-19        2.8786        3.0549        2.6919             947.0
# 57   2023-01-18        2.8189        3.0442        2.6823            1542.0
# 58   2023-01-17        2.7767        3.0385        2.6727             808.0
# 59   2023-01-16        2.7374        3.0328        2.6638            1439.0
# 60   2023-01-13        2.7011        3.0298        2.6554            3483.0
# 61   2023-01-12        2.5285        3.0115        2.6242            1377.0
# 62   2023-01-11        2.5032        3.0057        2.6156            1042.0
# 63   2023-01-10        2.5004        3.0074        2.6085             805.0
# 64   2023-01-09        2.4912        3.0019        2.6002             999.0
# 65   2023-01-06        2.4715        2.9980        2.5902             872.0
# 66   2023-01-05        2.4918        3.0008        2.5668            1684.0
# 67   2023-01-04        2.5201        3.0049        2.5621             904.0
# 68   2023-01-03        2.5722        3.0166        2.5587            1283.0
# 69   2022-12-30        2.6321        3.0294        2.5553            1243.0
# 70   2022-12-29        2.7776        3.0966        2.5395            1854.0
# 71   2022-12-28        2.8461        3.1214        2.5389            1109.0
# 72   2022-12-27        2.9044        3.1317        2.5392            1364.0
# 73   2022-12-23        2.9640        3.1415        2.5390            1870.0
# 74   2022-12-22        3.0256        3.1109        2.5100            1318.0
# 75   2022-12-21        3.0929        3.1141        2.5095            1478.0
# 262  2022-03-24        0.2492        0.2533        0.2149             808.0
# 263  2022-03-23        0.2418        0.2504        0.2125            1538.0
# 264  2022-03-22        0.2270        0.2444        0.2093            1967.0
# 265  2022-03-21        0.2205        0.2399        0.2075            2841.0
# 266  2022-03-18        0.2137        0.2367        0.2059            1735.0
# 340  2021-12-02        0.1516        0.1565        0.1433            1158.0
# 341  2021-12-01        0.1531        0.1572        0.1436            1421.0
# 342  2021-11-30        0.1550        0.1579        0.1439            2515.0
# 374  2021-10-14        0.1310        0.1359        0.1364            1933.0
#
#       timestamp  Indicator
# 1    1681297582       True
# 56   1681297582       True
# 57   1681297582       True
# 58   1681297582       True
# 59   1681297582       True
# 60   1681297582       True
# 61   1681297582       True
# 62   1681297582       True
# 63   1681297582       True
# 64   1681297582       True
# 65   1681297582       True
# 66   1681297582       True
# 67   1681297582       True
# 68   1681297582       True
# 69   1681297582       True
# 70   1681297582       True
# 71   1681297582       True
# 72   1681297582       True
# 73   1681297582       True
# 74   1681297582       True
# 75   1681297582       True
# 262  1681297582       True
# 263  1681297582       True
# 264  1681297582       True
# 265  1681297582       True
# 266  1681297582       True
# 340  1681297582       True
# 341  1681297582       True
# 342  1681297582       True
# 374  1681297582       True

# %%
DriverObjs:webdriver.firefox.webdriver.WebDriver=webdriver.Firefox();
DriverObjs.get('https://www.set.or.th/en/market/statistics/short-sell');
time.sleep(2);
print(DriverObjs.title);
DriverObjs.find_element(webdriver.common.by.By.XPATH,'//*[@id=\"__layout\"]/div/div[2]/div[3]/div/div/div[2]/div/div[2]/button').click();
pass; #similar to __asm__("nop")
time.sleep(2);
DriverObjs.close();
# Out:
# Short Selling - The Stock Exchange of Thailand

# %%
FileString:str='/Users/cedricyang/Downloads/Short Sales_10-04-2023 to 10-04-2023.xlsx';
ThaiSS_DF:pd.DataFrame=pd.read_excel(io=ThaiSS_FileStr,engine='openpyxl',header=5,index_col=0);
ThaiSS_DF=ThaiSS_DF[:200];
ThaiSS_DF=ThaiSS_DF.sort_values(by=['Turnover (Baht)','Symbol'],ascending=False)
ThaiSS_DF=ThaiSS_DF.reset_index();
ThaiSS_DF['USD Eqiv Amt']=(ThaiSS_DF['Turnover (Baht)'] / 34.12);
display(ThaiSS_DF[:30])
# Out:
#       Symbol  Volume (Shares)  Turnover (Baht)  \
# 0      BANPU       17357200.0      176193900.0
# 1        AOT        2315700.0      167356025.0
# 2      AOT-R        2032400.0      147175475.0
# 3        KTB        8018400.0      136270170.0
# 4      KTB-R        7190700.0      123250980.0
# 5       BDMS        3960400.0      120792200.0
# 6        BBL         706500.0      110383200.0
# 7      KBANK         742800.0       99502750.0
# 8      CPALL        1206800.0       75071575.0
# 9     ADVANC         332800.0       70603600.0
# 10      BH-R         301000.0       70359600.0
# 11   BANPU-R        6973700.0       70353340.0
# 12   CPALL-R         815500.0       50748300.0
# 13       BEM        5572800.0       49738685.0
# 14       CPF        2330100.0       48538750.0
# 15     CBG-R         548500.0       48357575.0
# 16      GULF         827500.0       44555450.0
# 17      COM7        1536000.0       42458525.0
# 18     BEM-R        4653900.0       41477400.0
# 19  ADVANC-R         179900.0       38141100.0
# 20        LH        3539600.0       34762795.0
# 21       CBG         376900.0       33272700.0
# 22   KBANK-R         240800.0       32273800.0
# 23     JMT-R         724500.0       31537325.0
# 24    GULF-R         561400.0       30154575.0
# 25    BDMS-R         982700.0       29972350.0
# 26       BTS        3568900.0       26848130.0
# 27      LH-R        2628700.0       25888025.0
# 28     CPF-R        1203400.0       25058320.0
# 29     BTS-R        3190600.0       23803700.0
#
#     % Short Sale Volume Comparing with Auto Matching  USD Eqiv Amt
# 0                                           0.207610  5.163948e+06
# 1                                           0.141451  4.904925e+06
# 2                                           0.124146  4.313466e+06
# 3                                           0.072792  3.993850e+06
# 4                                           0.065278  3.612280e+06
# 5                                           0.121559  3.540217e+06
# 6                                           0.090240  3.235147e+06
# 7                                           0.054728  2.916259e+06
# 8                                           0.083944  2.200222e+06
# 9                                           0.104945  2.069273e+06
# 10                                          0.101180  2.062122e+06
# 11                                          0.083412  2.061938e+06
# 12                                          0.056725  1.487348e+06
# 13                                          0.114497  1.457757e+06
# 14                                          0.243663  1.422589e+06
# 15                                          0.141603  1.417279e+06
# 16                                          0.113322  1.305846e+06
# 17                                          0.107286  1.244388e+06
# 18                                          0.095617  1.215633e+06
# 19                                          0.056729  1.117852e+06
# 20                                          0.139819  1.018839e+06
# 21                                          0.097302  9.751671e+05
# 22                                          0.017741  9.458910e+05
# 23                                          0.180606  9.243061e+05
# 24                                          0.076881  8.837800e+05
# 25                                          0.030163  8.784393e+05
# 26                                          0.114493  7.868737e+05
# 27                                          0.103838  7.587346e+05
# 28                                          0.125842  7.344174e+05
# 29                                          0.102357  6.976465e+05

# %%
DriverObjs2:webdriver.firefox.webdriver.WebDriver=webdriver.Firefox();
DriverObjs2.get('https://www.set.or.th/en/home');
time.sleep(2);
DriverObjs2.find_element(webdriver.common.by.By.XPATH,'/html/body/div/div/div/header/div[1]/div[1]/div[1]/div[3]/div/div[1]/input').click();
time.sleep(2);
TrendingQuote=DriverObjs2.find_element(webdriver.common.by.By.XPATH,'//*[@id="SearchDropdownSecurities"]');
print(TrendingQuote.text);
# Out:
# Popular Quote
# Last Update 12 Apr 2023 11:24:16
# BANPU
# Stock
# 9.85
# BANPU PUBLIC COMPANY LIMITED
# -0.15 (-1.50%)
# SCB
# Stock
# 105.00
# SCB X PUBLIC COMPANY LIMITED
# -1.00 (-0.94%)
# PTT
# Stock
# 31.50
# PTT PUBLIC COMPANY LIMITED
# 0.00 (0.00%)
# KBANK
# Stock
# 134.50
# KASIKORNBANK PUBLIC COMPANY LIMITED
# -0.50 (-0.37%)
# KTB
# Stock
# 17.10
# KRUNG THAI BANK PUBLIC COMPANY LIMITED
# -0.10 (-0.58%)

# %%
HtmlIO_File=open('HK_X_SS.html');
soupObj=bs4.BeautifulSoup(HtmlIO_File,'html.parser');
preTags:str=soupObj.select_one('pre').text;

SplitList:list=preTags.split('\n')[5:];
Spacing_Split:list=SplitList[50].split(" ");
print(Spacing_Split, " ***** ",len(Spacing_Split));
#convert a list to dataframe and setting the first few elements of the list as column header
print(SplitList[50], " Starting List Length ",len(SplitList[100]));
ObjFlag:bool=(Spacing_Split[2]=='');
ObjFlag2:bool=(Spacing_Split[5]=='');
print(ObjFlag)
print(ObjFlag2)
j=0;
for i in Spacing_Split:
    if (Spacing_Split[j]==''):
        Spacing_Split.remove('');
        Spacing_Split.remove( '');
        Spacing_Split.remove("");
        Spacing_Split.remove( "");
    j=j+1;
    continue;

print(Spacing_Split, " Length of list ",len(Spacing_Split));
# Out:
# ['', '', '', '', '548', '', 'SHENZHENEXPRESS', '', '', '', '', '', '', '', '', '', '', '48,000', '', '', '', '', '', '', '', '347,880']  *****  26
#     548  SHENZHENEXPRESS           48,000        347,880  Starting List Length  56
# True
# True
# ['548', 'SHENZHENEXPRESS', '48,000', '', '', '347,880']  Length of list  6
